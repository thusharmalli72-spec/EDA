# %%
import pandas as pd

# %%
df = pd.read_csv("stock_data.csv")

# %%
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2026-01-02  101.09  103.37  100.08  102.04   89377.0
# 1   2026-01-05  101.05  101.99   99.91  100.58   88404.0
# 2   2026-01-06  102.41  103.15   99.47  101.36   94045.0
# 3   2026-01-07  105.35  108.05  103.53  106.87   72352.0
# 4   2026-01-08  105.13  109.88  104.24  107.49   79790.0
# 5   2026-01-09  104.91  108.22  103.42  107.07   81919.0
# 6   2026-01-12  107.95  109.49  104.84  106.57   45600.0
# 7   2026-01-13  109.53  111.44  107.88     NaN   69124.0
# 8   2026-01-14  108.89  111.08  107.60  109.85   67643.0
# 9   2026-01-15  110.07  114.76  109.21  112.32   80764.0
# 10  2026-01-16  109.43  111.85  108.13  108.77   49007.0
# 11  2026-01-19  108.79  109.79  106.87  108.72  450000.0
# 12  2026-01-20  109.43  110.92  105.67  107.52   96835.0
# 13  2026-01-21  106.18  107.28  102.64  104.09   77410.0
# 14  2026-01-22  103.28  106.28  102.27  105.21   84080.0
# ...

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close   Volume
# 0  2026-01-02  101.09  103.37  100.08  102.04  89377.0
# 1  2026-01-05  101.05  101.99   99.91  100.58  88404.0
# 2  2026-01-06  102.41  103.15   99.47  101.36  94045.0
# 3  2026-01-07  105.35  108.05  103.53  106.87  72352.0
# 4  2026-01-08  105.13  109.88  104.24  107.49  79790.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50 non-null     object
#  1   Open    49 non-null     float64
#  2   High    49 non-null     float64
#  3   Low     50 non-null     float64
#  4   Close   49 non-null     float64
#  5   Volume  49 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.5+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      1
# High      1
# Low       0
# Close     1
# Volume    1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df["Price_delta"]=df["Close"]-df["Open"]
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11676\183733002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Price_delta"]=df["Close"]-df["Open"]
#          Date    Open    High     Low   Close    Volume  Price_delta
# 0  2026-01-02  101.09  103.37  100.08  102.04   89377.0         0.95
# 1  2026-01-05  101.05  101.99   99.91  100.58   88404.0        -0.47
# 2  2026-01-06  102.41  103.15   99.47  101.36   94045.0        -1.05
# 3  2026-01-07  105.35  108.05  103.53  106.87   72352.0         1.52
# 4  2026-01-08  105.13  109.88  104.24  107.49   79790.0         2.36
# 5  2026-01-09  104.91  108.22  103.42  107.07   81919.0         2.16
# 6  2026-01-12  107.95  109.49  104.84  106.57   45600.0        -1.38
# ...

# %%
df["Daily_Return"] = (df["Close"] - df["Open"] / df["Open"]) * 100
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11676\1273063116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Daily_Return"] = (df["Close"] - df["Open"] / df["Open"]) * 100
#          Date    Open    High     Low   Close    Volume  Price_delta  \
# 0  2026-01-02  101.09  103.37  100.08  102.04   89377.0         0.95
# 1  2026-01-05  101.05  101.99   99.91  100.58   88404.0        -0.47
# 2  2026-01-06  102.41  103.15   99.47  101.36   94045.0        -1.05
# 3  2026-01-07  105.35  108.05  103.53  106.87   72352.0         1.52
# 4  2026-01-08  105.13  109.88  104.24  107.49   79790.0         2.36
# 5  2026-01-09  104.91  108.22  103.42  107.07   81919.0         2.16
# ...

# %%
df["Volume"].mean()
# Out:
# np.float64(111812.21739130435)

# %%
df["Volume"].max()
# Out:
# 850000.0

# %%
# moving average of volumn 
df["Volume_MA_7"]=df["Volume"].rolling(7).mean()
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11676\74328092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Volume_MA_7"]=df["Volume"].rolling(7).mean()
#          Date    Open    High     Low   Close    Volume  Price_delta  \
# 0  2026-01-02  101.09  103.37  100.08  102.04   89377.0         0.95
# 1  2026-01-05  101.05  101.99   99.91  100.58   88404.0        -0.47
# 2  2026-01-06  102.41  103.15   99.47  101.36   94045.0        -1.05
# 3  2026-01-07  105.35  108.05  103.53  106.87   72352.0         1.52
# 4  2026-01-08  105.13  109.88  104.24  107.49   79790.0         2.36
# 5  2026-01-09  104.91  108.22  103.42  107.07   81919.0         2.16
# 6  2026-01-12  107.95  109.49  104.84  106.57   45600.0        -1.38
# ...

# %%
#identifying anomalies = finding error 
volume_mean = df["Volume"].mean()
volume_mean
# Out:
# np.float64(111812.21739130435)

# %%
volume_std = df["Volume"].std()
volume_std
# Out:
# 148250.65636907922

# %%
volume_threshold = volume_mean + (2 * volume_std)

# %%
anomalies = df[df["Volume"] > volume_threshold]
anomalies
# Out:
#          Date    Open    High     Low   Close    Volume  Price_delta  \
# 11 2026-01-19  108.79  109.79  106.87  108.72  450000.0        -0.07
# 27 2026-02-10   97.05   99.07   95.25   96.75  620000.0        -0.30
# 41 2026-03-02   94.30   97.07   92.95   96.54  850000.0         2.24
#
#     Daily_Return    Volume_MA_7
# 11       10772.0  122103.285714
# 27        9575.0  152979.285714
# 41        9554.0  184160.000000

# %%
# stock return distribution
mean_return = df["Daily_Return"].mean()
variance_return = df["Daily_Return"].var()
standard_return = df["Daily_Return"].std()

# %%
print("Daily Return Statistics")
print("Mean Return:", mean_return)
print("Variance:", variance_return)
print("Standard Deviation:", standard_return)
# Out:
# Daily Return Statistics
# Mean Return: 9888.45652173913
# Variance: 384800.87584541057
# Standard Deviation: 620.3232027301659

# %%
df
# Out:
#          Date    Open    High     Low   Close    Volume  Price_delta  \
# 0  2026-01-02  101.09  103.37  100.08  102.04   89377.0         0.95
# 1  2026-01-05  101.05  101.99   99.91  100.58   88404.0        -0.47
# 2  2026-01-06  102.41  103.15   99.47  101.36   94045.0        -1.05
# 3  2026-01-07  105.35  108.05  103.53  106.87   72352.0         1.52
# 4  2026-01-08  105.13  109.88  104.24  107.49   79790.0         2.36
# 5  2026-01-09  104.91  108.22  103.42  107.07   81919.0         2.16
# 6  2026-01-12  107.95  109.49  104.84  106.57   45600.0        -1.38
# 8  2026-01-14  108.89  111.08  107.60  109.85   67643.0         0.96
# 9  2026-01-15  110.07  114.76  109.21  112.32   80764.0         2.25
# 10 2026-01-16  109.43  111.85  108.13  108.77   49007.0        -0.66
# 11 2026-01-19  108.79  109.79  106.87  108.72  450000.0        -0.07
# 12 2026-01-20  109.43  110.92  105.67  107.52   96835.0        -1.91
# 13 2026-01-21  106.18  107.28  102.64  104.09   77410.0        -2.09
# ...
